# %%
from es_gpt import ESGPT
import pandas as pd

def get_text_from_paper(x):
    question_title = x['question_title']
    question_detail = x['question_detail']
    answer = x['answer']
    return question_title + question_detail + "\n" + answer

import os
os.environ['OPENAI_API_KEY']='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'
os.environ['OPENAI_GPT_ENGINE']='text-babbage-001	'
os.environ['OPENAI_GPT_MAX_TOKENS']='2000'

# Create an instance of the ESGPT class
esgpt = ESGPT(index_name="aha")

df=pd.read_csv('data/input_생리대_100.csv')

# %%
for _,row in df.iterrows():
    #메타데이터(전문가,스펙,q전문,날짜 등) 추가
    _dict = {'author':row['author'], 'date':row['date']}
    id = row['url']+row['author']

    # Index the paper in Elasticsearch
    text = get_text_from_paper(row)
    esgpt.index(doc_id=id, doc=_dict, text=text)
# Out:
# 1
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# ...

# %%
from elasticsearch import Elasticsearch

ES_URL='es-gpt:ZWFzdHVzMi5henVyZS5lbGFzdGljLWNsb3VkLmNvbSQ3MDM3MWI3MjIzZjA0MmFkYjIwNzI0YjIyMGUwYjRhMyQ0YTk4N2ZiNTdiYzI0YWQ0ODBhMmNjOWI2MDJiNWRjYQ=='
ES_USER='elastic'
ES_PASS=zg='elOB8e1FHTBDphOyy3Kk8bpn'
ES_CA_CERT='config/certs/http_ca.crt'

# %%
import tiktoken
import openai
from sentence_transformers import SentenceTransformer

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# ...

# %%
openai.api_key = os.environ["OPENAI_API_KEY"]
b=openai.Embedding.create(
        input='hello', engine='text-embedding-ada-002')['data'][0]['embedding']
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# ...
